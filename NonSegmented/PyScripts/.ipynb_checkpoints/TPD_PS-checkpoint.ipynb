# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt

def ProcessDataFile(filepath,TREE_NAME="ftree",plotPulses=False,branchesNameList=[],expPulse=True,numOfSamples=120,numOfPulses=1000):
    
    # --- 2. FILE & TREE ACCESS ---
    # Use 'with' for safe file handling
    segregatedCharge=[]
    hei=[]
    rows=5
    cols=5
    #plotPulses=True
    listOfPulses=[]
    plt.figure(figsize=(16,16))
    #branchList=['Energy','EnergyShort','Samples']
    #branchList=['Samples','Pulse']
    branchList=branchesNameList
    
    counter=0
    
    timingSamples = np.linspace(0,300,300)
    listOfSampledPulses=[]

    listOfSampledPulses=[]
    
    with uproot.open(filepath) as file:
        tree = file[TREE_NAME]
        
    
        # --- 3. DATA READING (Optimized) ---
        # Read only the first event (entry_stop=1) and the 'Samples' branch
        if plotPulses:
            data = tree.arrays(
                branchList, 
                entry_start=0, 
                entry_stop=numOfPulses, 
                library="ak"
            )
        else:
            data = tree.arrays(
                branchList,
                #entry_start=0, 
                #entry_stop=5000, 
                library="ak"
            )
        print("Total num of events : ",len(data))
        '''
        print(data["Energy"])
        binss=np.linspace(0,200,500)
        plt.hist(data["Energy"],histtype='step',bins=binss)
        plt.yscale("log")
        '''
        
        return data
        '''
        timePts = np.array([])
        pulse=np.array([])
        #print(data)
        '''
        
        '''
        for pulseNum in range(0,len(data)):
            
            pulse=data[pulseNum][pulseBranchName]
            #print(len(pulse))
            #print(pulse)
            
            #print(len(pulse))

           
            
            if len(pulse) > 16:
                #if not expPulse:
                #    pulse = np.concatenate((np.full(16,pulse[0]), pulse))
                #print(len(pulse))
                pulse=subtract_baseline(pulse,expPulse=expPulse)
                mask = pulse < 0;
                pulse=pulse[mask]

                                  
            #if len(pulse) > 10 and pulseNum < 16:
            if len(pulse) > 16 :
                padding_amount = numOfSamples - len(pulse)
                # Pad (0 at the start, padding_amount at the end)
                pulse = np.pad(pulse, (0, padding_amount), mode='constant')
                #print("@@@@@@@@@@@@@@@@@@@@@@@@@@")
                #print(pulse)
                #continue
                #if not expPulse:
                #    pulse = -1.*pulse
                timePts=np.linspace(0,len(pulse),len(pulse))

                #print("@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@")
                #print(pulse)
                
                #listOfSampledPulses.append(pulse.tolist())
                #counter += 1
                #plt.subplot(4,4,counter)
                #plt.plot(timePts,pulse)
                try:
                    popt=FitPulse(np.asarray(timePts.tolist()),np.asarray(pulse.tolist()))
                    fitted_pulse = pulse_model(timePts, *popt)
                    #sampled_pulse = pulse_model(timingSamples, *popt)
                    #listOfSampledPulses.append(max_normalize(sampled_pulse))
                    #listOfSampledPulses.append(sampled_pulse)
                    
                    r2 = r2_score(pulse, fitted_pulse)
                    if 0 and r2 > 0.9:
                        print(f"================= {counter} ======================")
                        print(f"Pulse length : {len(counts)}")
                        print(f"R-squared: {r2:.3f}")

                    
                    if r2 > 0.9 :
                        counter+=1
                        listOfSampledPulses.append(pulse.tolist())
                        #print(len(pulse))
                        #pulseLenList.append(len(counts))
                        if counter <= 16:
                            plt.subplot(4,4,counter)
                            #plt.scatter(timePts,pulse,marker=".",color="blue")
                            plt.plot(timePts,pulse)
                            plt.plot(timePts,fitted_pulse,'r-')
                            #counter += 1
                            #plt.subplot(4,4,counter)
                            #plt.plot(timingSamples,sampled_pulse,marker=".",color="green")
                except ValueError as e:
                    #print(f"Skipping event due to bounds error: {e}")
                    continue  # Skips the rest of this loop iteration
                except RuntimeError:
                    #print("Skipping event: Fit failed to converge.")
                    continue

        #print(listOfSampledPulses)
        listOfSampledPulses = np.array(listOfSampledPulses)
        #result = np.zeros((len(ragged_data), N), dtype=int)
        
        return listOfSampledPulses,timePts
        '''

# %%
SOURCE_FILE_PATH="../SampleData/DataF_TPD_PS_Na22_Waves_5min.root"
branchesNameList=["Energy","Samples"]
data=ProcessDataFile(SOURCE_FILE_PATH,"Data_F",branchesNameList=branchesNameList,plotPulses=False,numOfPulses=100)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 3
#       1 SOURCE_FILE_PATH="../SampleData/DataF_TPD_PS_Na22_Waves_5min.root"
#       2 branchesNameList=["Energy","Samples"]
# ----> 3 data=ProcessDataFile(SOURCE_FILE_PATH,"Data_F",branchesNameList=branchesNameList,plotPulses=False,numOfPulses=100)
#       4 plt.figure(figsize=(5,5))
#       5 binss=np.linspace(0,200,500)
#
# Cell In[21], line 41, in ProcessDataFile(filepath, TREE_NAME, plotPulses, branchesNameList, expPulse, numOfSamples, numOfPulses)
#      34     data = tree.arrays(
#      35         branchList,
#      36         entry_start=0,
#      37         entry_stop=numOfPulses,
#      38         library="ak"
#      39     )
#      40 else:
# ---> 41     data = tree.arrays(
#      42         branchList,
#      43         #entry_start=0,
#      44         #entry_stop=5000,
#      45         library="ak"
#      46     )
#      47 print("Total num of events : ",len(data))
#      48 '''
#      49 print(data["Energy"])
#      50 binss=np.linspace(0,200,500)
#      51 plt.hist(data["Energy"],histtype='step',bins=binss)
#      52 plt.yscale("log")
#      53 '''
#
# File ~/WorkingEnv/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:889, in HasBranches.arrays(self, expressions, cut, filter_name, filter_typename, filter_branch, aliases, language, entry_start, entry_stop, decompression_executor, interpretation_executor, array_cache, library, ak_add_doc, how)
#     886                 ranges_or_baskets.append((branch, basket_num, range_or_basket))
#     888 interp_options = {"ak_add_doc": ak_add_doc}
# --> 889 _ranges_or_baskets_to_arrays(
#     890     self,
#     891     ranges_or_baskets,
#     892     branchid_interpretation,
#     893     entry_start,
#     894     entry_stop,
#     895     decompression_executor,
#     896     interpretation_executor,
#     897     library,
#     898     arrays,
#     899     False,
#     900     interp_options,
#     901 )
#     903 # no longer needed; save memory
#     904 del ranges_or_baskets
#
# File ~/WorkingEnv/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:3198, in _ranges_or_baskets_to_arrays(hasbranches, ranges_or_baskets, branchid_interpretation, entry_start, entry_stop, decompression_executor, interpretation_executor, library, arrays, update_ranges_or_baskets, interp_options)
#    3195     decompression_executor.submit(chunk_to_basket, obj, *args)
#    3197 elif isinstance(obj, uproot.models.TBasket.Model_TBasket):
# -> 3198     interpretation_executor.submit(basket_to_array, obj)
#    3200 elif obj is None:
#    3201     pass
#
# File ~/WorkingEnv/lib/python3.10/site-packages/uproot/source/futures.py:104, in TrivialExecutor.submit(self, task, *args, **kwargs)
#     100 def submit(self, task, /, *args, **kwargs):
#     101     """
#     102     Immediately runs ``task(*args)``.
#     103     """
# --> 104     return TrivialFuture(task(*args, **kwargs))
#
# File ~/WorkingEnv/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:3165, in _ranges_or_baskets_to_arrays.<locals>.basket_to_array(basket)
#    3162     len_basket_arrays = len(basket_arrays)
#    3164 if len_basket_arrays == branchid_num_baskets[branch.cache_key]:
# -> 3165     arrays[branch.cache_key] = interpretation.final_array(
#    3166         basket_arrays,
#    3167         entry_start,
#    3168         entry_stop,
#    3169         branch.entry_offsets,
#    3170         library,
#    3171         branch,
#    3172         interp_options,
#    3173     )
#    3174     with _basket_arrays_lock:
#    3175         # no longer needed, save memory
#    3176         basket_arrays.clear()
#
# File ~/WorkingEnv/lib/python3.10/site-packages/uproot/interpretation/objects.py:576, in AsObjects.final_array(self, basket_arrays, entry_start, entry_stop, entry_offsets, library, branch, options)
#     564     output = numpy.concatenate(trimmed)
#     566 self.hook_before_library_finalize(
#     567     basket_arrays=basket_arrays,
#     568     entry_start=entry_start,
#    (...)
#     573     output=output,
#     574 )
# --> 576 output = library.finalize(
#     577     output, branch, self, entry_start, entry_stop, options
#     578 )
#     580 self.hook_after_final_array(
#     581     basket_arrays=basket_arrays,
#     582     entry_start=entry_start,
#    (...)
#     588     options=options,
#     589 )
#     591 return output
#
# File ~/WorkingEnv/lib/python3.10/site-packages/uproot/interpretation/library.py:583, in Awkward.finalize(self, array, branch, interpretation, entry_start, entry_stop, options)
#     577 elif isinstance(interpretation, uproot.interpretation.objects.AsObjects):
#     578     form = json.loads(
#     579         interpretation.awkward_form(interpretation.branch.file).to_json()
#     580     )
#     581     return _awkward_add_doc(
#     582         awkward,
# --> 583         _object_to_awkward_array(awkward, form, array),
#     584         branch,
#     585         ak_add_doc,
#     586     )
#     588 elif array.dtype.names is not None:
#     589     length, shape = array.shape[0], array.shape[1:]
#
# File ~/WorkingEnv/lib/python3.10/site-packages/uproot/interpretation/library.py:469, in _object_to_awkward_array(awkward, form, array)
#     468 def _object_to_awkward_array(awkward, form, array):
# --> 469     unlabeled = awkward.from_iter(
#     470         (_object_to_awkward_json(form, x) for x in array),
#     471         highlevel=False,
#     472     )
#     473     return awkward.Array(_awkward_json_to_array(awkward, form, unlabeled))
#
# File ~/WorkingEnv/lib/python3.10/site-packages/awkward/_dispatch.py:42, in named_high_level_function.<locals>.dispatch(*args, **kwargs)
#      38 @wraps(func)
#      39 def dispatch(*args, **kwargs):
#      40     # NOTE: this decorator assumes that the operation is exposed under `ak.`
#      41     with OperationErrorContext(name, args, kwargs):
# ---> 42         gen_or_result = func(*args, **kwargs)
#      43         if isgenerator(gen_or_result):
#      44             array_likes = next(gen_or_result)
#
# File ~/WorkingEnv/lib/python3.10/site-packages/awkward/operations/ak_from_iter.py:70, in from_iter(iterable, allow_record, highlevel, behavior, attrs, initial, resize)
#      18 @high_level_function()
#      19 def from_iter(
#      20     iterable,
#    (...)
#      27     resize=8,
#      28 ):
#      29     """
#      30     Args:
#      31         iterable (Python iterable): Data to convert into an Awkward Array.
#    (...)
#      68     See also #ak.to_list.
#      69     """
# ---> 70     return _impl(iterable, highlevel, behavior, allow_record, initial, resize, attrs)
#
# File ~/WorkingEnv/lib/python3.10/site-packages/awkward/operations/ak_from_iter.py:100, in _impl(iterable, highlevel, behavior, allow_record, initial, resize, attrs)
#      97     iterable = list(iterable)
#      99 builder = _ext.ArrayBuilder(initial=initial, resize=resize)
# --> 100 builder.fromiter(iterable)
#     102 formstr, length, buffers = builder.to_buffers()
#     103 form = ak.forms.from_json(formstr)
#
# File ~/WorkingEnv/lib/python3.10/site-packages/uproot/interpretation/library.py:470, in <genexpr>(.0)
#     468 def _object_to_awkward_array(awkward, form, array):
#     469     unlabeled = awkward.from_iter(
# --> 470         (_object_to_awkward_json(form, x) for x in array),
#     471         highlevel=False,
#     472     )
#     473     return awkward.Array(_awkward_json_to_array(awkward, form, unlabeled))
#
# KeyboardInterrupt:
